# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
planets = sns.load_dataset('planets') # This is fetched online using load_dataset.
planets.shape
# Out:
# (1035, 6)

# %%
planets.columns
# Out:
# Index(['method', 'number', 'orbital_period', 'mass', 'distance', 'year'], dtype='object')

# %%
planets.head()
# Out:
#             method  number  orbital_period   mass  distance  year
# 0  Radial Velocity       1         269.300   7.10     77.40  2006
# 1  Radial Velocity       1         874.774   2.21     56.95  2008
# 2  Radial Velocity       1         763.000   2.60     19.84  2011
# 3  Radial Velocity       1         326.030  19.40    110.62  2007
# 4  Radial Velocity       1         516.220  10.50    119.47  2009

# %% [markdown]
# ## For a dataframe, sum, mean etc are calculated for each column

# %%
df = pd.DataFrame({'A': np.random.rand(5), 'B': np.random.rand(5)})
df
# Out:
#           A         B
# 0  0.803553  0.147392
# 1  0.791597  0.726461
# 2  0.945554  0.281477
# 3  0.934171  0.166317
# 4  0.924644  0.202168

# %%
df.sum()
# Out:
# A    4.399519
# B    1.523815
# dtype: float64

# %%
df.mean()
# Out:
# A    0.879904
# B    0.304763
# dtype: float64

# %% [markdown]
# ## We can aggregate for each row by using 'axis'
#
# ### Note:
#
# <blockquote>A DataFrame object has two axes: “axis 0” and “axis 1”. “axis 0” represents rows and “axis 1” represents columns.</blockquote>
#
# ## Note: The axis 0 or 1 decides the direction things will be computed.
#
# ## 0 is Downward direction (as rows ascend downwards from top to bottom)
# ## 1 is left to right (as columns advance)

# %%
df.sum(axis=0) # Or axis='rows'
# Out:
# A    4.399519
# B    1.523815
# dtype: float64

# %%
# There is a convinient 'describe' method giving everything for the DF.

planets.dropna().describe()
# Out:
#           number  orbital_period        mass    distance         year
# count  498.00000      498.000000  498.000000  498.000000   498.000000
# mean     1.73494      835.778671    2.509320   52.068213  2007.377510
# std      1.17572     1469.128259    3.636274   46.596041     4.167284
# min      1.00000        1.328300    0.003600    1.350000  1989.000000
# 25%      1.00000       38.272250    0.212500   24.497500  2005.000000
# 50%      1.00000      357.000000    1.245000   39.940000  2009.000000
# 75%      2.00000      999.600000    2.867500   59.332500  2011.000000
# max      6.00000    17337.500000   25.000000  354.000000  2014.000000

# %%
# Counter checking values.
planets.dropna().mean(axis=0)
# Out:
# number               1.734940
# orbital_period     835.778671
# mass                 2.509320
# distance            52.068213
# year              2007.377510
# dtype: float64

# %% [markdown]
# All methods available table
#
# ## **Aggregation	- Description**
# - count()	Total number of items
# -first(), last()	First and last item
# -mean(), median()	Mean and median
# -min(), max()	Minimum and maximum
# -std(), var()	Standard deviation and variance
# -mad()	Mean absolute deviation
# -prod()	Product of all items
# -sum()	Sum of all items

# %% [markdown]
# # GroupBy: Split, Apply, Combine

# %%
df = pd.DataFrame({'key': ['A', 'B', 'C', 'A', 'B', 'C'],
                   'data': range(6)})
df
# Out:
#   key  data
# 0   A     0
# 1   B     1
# 2   C     2
# 3   A     3
# 4   B     4
# 5   C     5

# %%
# We create a groupby object and using that, we can do all sort of computations.

gr_df = df.groupby('key')

# %%
gr_df.sum()
# Out:
#      data
# key
# A       3
# B       5
# C       7

# %%
planets_year_gr = planets.dropna().groupby('year')
planets_year_gr.count().head()
# Out:
#       method  number  orbital_period  mass  distance
# year
# 1989       1       1               1     1         1
# 1995       1       1               1     1         1
# 1996       4       4               4     4         4
# 1997       1       1               1     1         1
# 1998       5       5               5     5         5

# %%
# Get count sorted by hishest distance to lowest.

planets_year_gr.count().sort_values('distance')[::-1].head()
# Out:
#       method  number  orbital_period  mass  distance
# year
# 2011      90      90              90    90        90
# 2009      70      70              70    70        70
# 2008      43      43              43    43        43
# 2010      41      41              41    41        41
# 2005      34      34              34    34        34

# %%
# We could also get just a column we are interested in.

orbital_period_series = planets_year_gr.mean()['orbital_period']
orbital_period_series
# Out:
# year
# 1989      83.888000
# 1995       4.230785
# 1996     275.145383
# 1997      39.845000
# 1998     114.310661
# 1999     591.477789
# 2000     572.027671
# 2001     792.019727
# 2002    1003.144581
# 2003     789.289313
# 2004     787.419733
# 2005     620.300633
# 2006     785.564764
# 2007     478.827107
# 2008     741.466230
# 2009    1381.749559
# 2010     819.593669
# 2011     603.793312
# 2012    1965.938509
# 2013     357.501831
# 2014    3639.500000
# Name: orbital_period, dtype: float64

# %% [markdown]
# ### As you can see, what we get is a Series.

# %%
type(orbital_period_series)
# Out:
# pandas.core.series.Series

# %%
for year, group in planets_year_gr:
    print('{0:10} shape={1}'.format(year, group.shape))
    
# Note: The count() column also gives us the same stats as shape. 
# shape=(90, 6) is 90 records/rows each having 6 values.
# Out:
#       1989 shape=(1, 6)
#       1995 shape=(1, 6)
#       1996 shape=(4, 6)
#       1997 shape=(1, 6)
#       1998 shape=(5, 6)
#       1999 shape=(14, 6)
#       2000 shape=(14, 6)
#       2001 shape=(11, 6)
#       2002 shape=(31, 6)
#       2003 shape=(22, 6)
#       2004 shape=(15, 6)
#       2005 shape=(34, 6)
#       2006 shape=(20, 6)
#       2007 shape=(27, 6)
#       2008 shape=(43, 6)
#       2009 shape=(70, 6)
#       2010 shape=(41, 6)
#       2011 shape=(90, 6)
#       2012 shape=(23, 6)
#       2013 shape=(29, 6)
#       2014 shape=(2, 6)

# %% [markdown]
# ## Dispatch Methods.
#
# ### These can do things automatically. E.g:
# - describe

# %%
# Get me count of each method 
planets.groupby('method')['number'].count()
# Out:
# method
# Astrometry                         2
# Eclipse Timing Variations          9
# Imaging                           38
# Microlensing                      23
# Orbital Brightness Modulation      3
# Pulsar Timing                      5
# Pulsation Timing Variations        1
# Radial Velocity                  553
# Transit                          397
# Transit Timing Variations          4
# Name: number, dtype: int64

# %%
planets.groupby('method')['year'].describe()
# Out:
#                                count         mean       std     min      25%  \
# method
# Astrometry                       2.0  2011.500000  2.121320  2010.0  2010.75
# Eclipse Timing Variations        9.0  2010.000000  1.414214  2008.0  2009.00
# Imaging                         38.0  2009.131579  2.781901  2004.0  2008.00
# Microlensing                    23.0  2009.782609  2.859697  2004.0  2008.00
# Orbital Brightness Modulation    3.0  2011.666667  1.154701  2011.0  2011.00
# Pulsar Timing                    5.0  1998.400000  8.384510  1992.0  1992.00
# Pulsation Timing Variations      1.0  2007.000000       NaN  2007.0  2007.00
# Radial Velocity                553.0  2007.518987  4.249052  1989.0  2005.00
# Transit                        397.0  2011.236776  2.077867  2002.0  2010.00
# Transit Timing Variations        4.0  2012.500000  1.290994  2011.0  2011.75
#
#                                   50%      75%     max
# method
# Astrometry                     2011.5  2012.25  2013.0
# Eclipse Timing Variations      2010.0  2011.00  2012.0
# Imaging                        2009.0  2011.00  2013.0
# Microlensing                   2010.0  2012.00  2013.0
# Orbital Brightness Modulation  2011.0  2012.00  2013.0
# Pulsar Timing                  1994.0  2003.00  2011.0
# Pulsation Timing Variations    2007.0  2007.00  2007.0
# Radial Velocity                2009.0  2011.00  2014.0
# Transit                        2012.0  2013.00  2014.0
# Transit Timing Variations      2012.5  2013.25  2014.0

# %%
planets_year_gr['distance'].describe()

# Note: We have NaN data wherever count is 1.
# Out:
#       count       mean        std    min      25%     50%      75%     max
# year
# 1989    1.0  40.570000        NaN  40.57  40.5700  40.570  40.5700   40.57
# 1995    1.0  15.360000        NaN  15.36  15.3600  15.360  15.3600   15.36
# 1996    4.0  13.920000   1.288746  12.53  13.2350  13.775  14.4600   15.60
# 1997    1.0  17.430000        NaN  17.43  17.4300  17.430  17.4300   17.43
# 1998    5.0  26.302000  16.855839   4.70  19.7200  21.290  37.8800   47.92
# 1999   14.0  29.795000  14.260006  10.91  17.9025  29.350  38.5800   59.03
# 2000   14.0  28.340000  12.821017   3.22  20.4425  32.865  36.9500   42.43
# 2001   11.0  37.212727  18.877052  14.08  23.0350  34.600  43.7400   77.82
# 2002   31.0  44.396129  23.294079  12.53  32.2850  37.440  49.1450  121.36
# 2003   22.0  44.505909  30.735342  11.11  28.2200  36.420  50.0700  133.16
# 2004   15.0  42.712000  17.680615  12.53  35.5150  43.990  51.4150   74.46
# 2005   34.0  46.361471  50.525485   4.70  21.1975  35.835  54.7075  300.30
# 2006   20.0  44.394500  29.835589   8.77  16.1575  45.745  59.0100   94.07
# 2007   27.0  62.292593  29.907420   4.54  46.5250  54.230  80.8400  127.55
# 2008   43.0  56.967674  39.976826   4.94  26.1500  51.870  74.7450  164.20
# 2009   70.0  59.569143  42.536908   8.52  34.9650  49.680  68.1650  214.00
# 2010   41.0  49.539268  39.874705   4.70  20.2100  39.390  65.6200  223.21
# 2011   90.0  59.772889  64.245525   6.06  24.5100  34.720  78.5150  354.00
# 2012   23.0  64.977826  85.740945   1.35  20.8850  42.990  54.6100  352.11
# 2013   29.0  58.289310  48.056344   6.80  20.0300  52.030  68.5900  178.00
# 2014    2.0  44.510000  33.983552  20.48  32.4950  44.510  56.5250   68.54

# %% [markdown]
# ## Aggregate, filter, transform, apply
#
# #### We have more methods available with the group by object.

# %%
# Test DataFrame.

rng = np.random.RandomState(0)
df = pd.DataFrame({'key': ['A', 'B', 'C', 'A', 'B', 'C'],
                   'data1': range(6),
                   'data2': rng.randint(0, 10, 6)},
                   columns = ['key', 'data1', 'data2'])
df
# Out:
#   key  data1  data2
# 0   A      0      5
# 1   B      1      0
# 2   C      2      3
# 3   A      3      3
# 4   B      4      7
# 5   C      5      9

# %% [markdown]
# ### Aggregation

# %%
# We can aggregate specific things.

df.groupby('key').aggregate(['min', np.median, max])
# Out:
#     data1            data2
#       min median max   min median max
# key
# A       0    1.5   3     3    4.0   5
# B       1    2.5   4     0    3.5   7
# C       2    3.5   5     3    6.0   9

# %%
# We can aggregate for specific column and specific methods.

df.groupby('key').aggregate({'data1': 'min',
                             'data2': 'max'})
# Out:
#      data1  data2
# key
# A        0      5
# B        1      7
# C        2      9

# %%
# We can filter data.
df_sum = df.groupby('key').sum()
df_sum[df_sum > 5].fillna(0) # Here the NaN values, I am replacing with 0
# Out:
#      data1  data2
# key
# A      0.0      8
# B      0.0      7
# C      7.0     12

# %% [markdown]
# ## Transformation
#
# #### We can generate new values using some calculation.

# %%
df.groupby('key').transform(lambda x: x - x.mean())
# Out:
#    data1  data2
# 0   -1.5    1.0
# 1   -1.5   -3.5
# 2   -1.5   -3.0
# 3    1.5   -1.0
# 4    1.5    3.5
# 5    1.5    3.0

# %% [markdown]
# ## Apply
#
# #### The apply() function lets you use a function to calculate something.

# %%
def multiply_by(x):
    x['data1'] = (x['data2'] * 100)/np.pi
    return x
    
df.groupby('key').apply(multiply_by)
# Out:
#   key       data1  data2
# 0   A  159.154943      5
# 1   B    0.000000      0
# 2   C   95.492966      3
# 3   A   95.492966      3
# 4   B  222.816920      7
# 5   C  286.478898      9
